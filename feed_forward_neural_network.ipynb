# %% [markdown]
# <a href="https://colab.research.google.com/github/YADHUSUDHAN/AIL411-DEEP-LEARNING-LAB-KTU/blob/main/feed_forward_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Libraries**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading and Preprocessing CIFAR-10 Dataset**

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train, X_test = X_train / 255.0, X_test / 255.0
y_train, y_test = to_categorical(y_train,10), to_categorical(y_test,10)

# %% [markdown]
# **Creating the Neural Network Model**

# %%
model = Sequential([
    Dense(256, activation='relu', input_shape=(32*32*3,)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# %% [markdown]
# **Compiling the Model**

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# **Training the Model**

# %%
history = model.fit(X_train.reshape(-1, 32*32*3),y_train,validation_split=0.2,epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 625/625 [==============================] - 13s 20ms/step - loss: 1.8819 - accuracy: 0.3157 - val_loss: 1.7437 - val_accuracy: 0.3719
# Epoch 2/10
# 625/625 [==============================] - 12s 19ms/step - loss: 1.6937 - accuracy: 0.3924 - val_loss: 1.6819 - val_accuracy: 0.3955
# Epoch 3/10
# 625/625 [==============================] - 12s 18ms/step - loss: 1.6120 - accuracy: 0.4207 - val_loss: 1.6113 - val_accuracy: 0.4306
# Epoch 4/10
# 625/625 [==============================] - 11s 17ms/step - loss: 1.5561 - accuracy: 0.4444 - val_loss: 1.5778 - val_accuracy: 0.4380
# Epoch 5/10
# 625/625 [==============================] - 12s 19ms/step - loss: 1.5085 - accuracy: 0.4602 - val_loss: 1.5777 - val_accuracy: 0.4393
# Epoch 6/10
# 625/625 [==============================] - 12s 20ms/step - loss: 1.4759 - accuracy: 0.4688 - val_loss: 1.5248 - val_accuracy: 0.4495
# Epoch 7/10
# ...

# %% [markdown]
# **Evaluating the Model**

# %%
test_loss, test_accuracy = model.evaluate(X_test.reshape(-1, 32*32*3), y_test)
print("Test accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.4471 - accuracy: 0.4860
# Test accuracy: 0.4860000014305115

# %% [markdown]
# **Plotting Learning Curves**

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
